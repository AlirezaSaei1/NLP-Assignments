# %% [markdown]
# # ASR for Farsi

# %% [markdown]
# ### Import required libraries

# %%
# !pip install datasets transformers librosa torchaudio hazm num2fawords jiwer accelerate

# %%
import json
import time

import re
from hazm import Normalizer

import torch
import torchaudio
import torchaudio.transforms as transforms
import librosa

import numpy as np
from jiwer import wer

from datasets import load_dataset, Audio, load_metric

from transformers import Wav2Vec2CTCTokenizer, Wav2Vec2FeatureExtractor, Wav2Vec2Processor, DataCollatorWithPadding
from transformers import Wav2Vec2ForCTC, TrainingArguments, Trainer

# %% [markdown]
# ### Load dataset from HuggingFace

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
common_voice_train = load_dataset("mozilla-foundation/common_voice_6_1", "fa", split="train")
common_voice_test = load_dataset("mozilla-foundation/common_voice_6_1", "fa", split="test")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# ### Remove Unnecessary Columns

# %%
columns_to_remove = ['down_votes', 'gender', 'locale', 'segment', 'up_votes', 'accent', 'age', 'client_id']

print("Train Set Columns (Before Drop):", common_voice_train.column_names)
print("Test Set Columns (Before Drop):", common_voice_test.column_names)

common_voice_train = common_voice_train.remove_columns(columns_to_remove)
common_voice_test = common_voice_test.remove_columns(columns_to_remove)

print("Train Set Columns (After Drop):", common_voice_train.column_names)
print("Test Set Columns (After Drop):", common_voice_test.column_names)
# Out:
# Train Set Columns (Before Drop): ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment']
# Test Set Columns (Before Drop): ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment']
# Train Set Columns (After Drop): ['path', 'audio', 'sentence']
# Test Set Columns (After Drop): ['path', 'audio', 'sentence']

# %% [markdown]
# ### Filter Audio

# %%
def filter_train_audio(batch):
    duration = len(batch["audio"]["array"]) / batch["audio"]["sampling_rate"]
    return 4.0 <= duration <= 6.0

def filter_test_audio(batch):
    duration = len(batch["audio"]["array"]) / batch["audio"]["sampling_rate"]
    return duration < 15.0

print("Common Voice Train Length (Before Filter):", len(common_voice_train))
print("Common Voice Test Length (Before Filter):", len(common_voice_test))

common_voice_train = common_voice_train.filter(filter_train_audio)
common_voice_test = common_voice_test.filter(filter_test_audio)

print("Common Voice Train Length (After Filter):", len(common_voice_train))
print("Common Voice Test Length (After Filter):", len(common_voice_test))
# Out:
# Common Voice Train Length (Before Filter): 7593
# Common Voice Test Length (Before Filter): 5213
# Common Voice Train Length (After Filter): 2217
# Common Voice Test Length (After Filter): 5212

# %% [markdown]
# ### Preprocessing

# %%
chars_to_ignore = [
    ",", "?", ".", "!", "-", ";", ":", '""', "%", "'", '"', "�", "&",
    "#", "!", "؟", "?", "«", "»", "،", "(", ")", "؛", "'ٔ", "٬",'ٔ', ",", "?",
    ".", "!", "-", ";", ":",'"',"“", "%", "‘", "”", "=", "–", "…", "_", "”", '“', '„',
    'ā', 'š'
]


chars_to_mapping = {
    'ك': 'ک', 'دِ': 'د', 'بِ': 'ب', 'زِ': 'ز', 'ذِ': 'ذ', 'شِ': 'ش', 'سِ': 'س', 'ى': 'ی',
    'ي': 'ی', 'أ': 'ا', 'ؤ': 'و', "ے": "ی", "ۀ": "ه", "ﭘ": "پ", "ﮐ": "ک", "ﯽ": "ی",
    "ﺎ": "ا", "ﺑ": "ب", "ﺘ": "ت", "ﺧ": "خ", "ﺩ": "د", "ﺱ": "س", "ﻀ": "ض", "ﻌ": "ع",
    "ﻟ": "ل", "ﻡ": "م", "ﻢ": "م", "ﻪ": "ه", "ﻮ": "و", 'ﺍ': "ا", 'ة': "ه",
    'ﯾ': "ی", 'ﯿ': "ی", 'ﺒ': "ب", 'ﺖ': "ت", 'ﺪ': "د", 'ﺮ': "ر", 'ﺴ': "س", 'ﺷ': "ش",
    'ﺸ': "ش", 'ﻋ': "ع", 'ﻤ': "م", 'ﻥ': "ن", 'ﻧ': "ن", 'ﻭ': "و", 'ﺭ': "ر", "ﮔ": "گ",

    # "ها": "  ها", "ئ": "ی",
    "۱۴ام": "۱۴ ام",

    "a": " ای ", "b": " بی ", "c": " سی ", "d": " دی ", "e": " ایی ", "f": " اف ",
    "g": " جی ", "h": " اچ ", "i": " آی ", "j": " جی ", "k": " کی ", "l": " ال ",
    "m": " ام ", "n": " ان ", "o": " او ", "p": " پی ", "q": " کیو ", "r": " آر ",
    "s": " اس ", "t": " تی ", "u": " یو ", "v": " وی ", "w": " دبلیو ", "x": " اکس ",
    "y": " وای ", "z": " زد ",
    "\u200c": " ", "\u200d": " ", "\u200e": " ", "\u200f": " ", "\ufeff": " ",
}

# %%
normalizer = Normalizer()

def preprocess_text(text):
    text = normalizer.normalize(text)
    text = text.lower()
    escaped_chars_to_ignore = [re.escape(char) for char in chars_to_ignore]
    text = re.sub(f"[{''.join(escaped_chars_to_ignore)}]", '', text)
    for old, new in chars_to_mapping.items():
        text = text.replace(old, new)
    return text

common_voice_train = common_voice_train.map(lambda batch: {"sentence": preprocess_text(batch["sentence"])})
common_voice_test = common_voice_test.map(lambda batch: {"sentence": preprocess_text(batch["sentence"])})

# %%
for i in range(3):
  print("Data", i)
  print(common_voice_train[i]["sentence"])
  print(common_voice_test[i]["sentence"])
# Out:
# Data 0
# چه جوری آخه برانکو با دست خالی تیمشو برد فینال
# از هم جداشدن خیلی سخته
# Data 1
# اون میوه هات رو بردار
# بله مطمئن باشید هستم
# Data 2
#  خوبه که جامعه پزشکی
# تقریبا صدو پنجاه گز دورتر از جاده

# %% [markdown]
# ### Create Character Dictionary

# %%
def extract_all_chars(batch):
    all_text = " ".join(batch["sentence"])
    vocab = list(set(all_text))
    return {"vocab": [vocab], "all_text": [all_text]}

vocab_train = common_voice_train.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=common_voice_train.column_names)
vocab_test = common_voice_test.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=common_voice_test.column_names)

vocab_list = list(set(vocab_train["vocab"][0]) | set(vocab_test["vocab"][0]))
vocab_dict = {v: k for k, v in enumerate(vocab_list)}

vocab_dict["|"] = vocab_dict.pop(" ")
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
vocab_dict["<s>"] = len(vocab_dict)
vocab_dict["</s>"] = len(vocab_dict)
# Out:
# Map:   0%|          | 0/2217 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5212 [00:00<?, ? examples/s]

# %%
print("Dictionary Length:", len(vocab_dict))
print(vocab_dict)
# Out:
# Dictionary Length: 40
# {'ش': 0, 'خ': 1, 'ک': 2, 'غ': 3, 'ن': 4, 'ء': 5, 'ط': 6, 'ظ': 7, 'د': 8, 'ر': 9, 'ا': 10, 'ح': 11, 'ذ': 12, 'ب': 13, 'چ': 14, 'ج': 16, 'س': 17, 'ئ': 18, 'و': 19, 'ت': 20, 'ژ': 21, 'ز': 22, 'ی': 23, 'پ': 24, 'ل': 25, 'ه': 26, 'م': 27, 'ق': 28, 'ض': 29, 'ف': 30, 'ع': 31, 'ص': 32, 'گ': 33, 'ث': 34, 'آ': 35, '|': 15, '[UNK]': 36, '[PAD]': 37, '<s>': 38, '</s>': 39}

# %% [markdown]
# ### Save unique characters in JSON

# %%
vocab_file = "vocab.json"
with open(vocab_file, 'w') as vf:
    json.dump(vocab_dict, vf)

# %% [markdown]
# ### Resample audio to 16kHz

# %%
def resample_audio(batch):
    waveform = torch.tensor(batch["audio"]["array"], dtype=torch.float32).unsqueeze(0)
    resampled_waveform = transforms.Resample(orig_freq=48000, new_freq=16000)(waveform)
    batch["audio"]["array"] = resampled_waveform.squeeze(0).numpy()
    batch["audio"]["sampling_rate"] = 16000
    return batch

def resample_audio_librosa(batch):
    y, sr = librosa.load(batch["audio"]["path"], sr=48000)
    y_resampled = librosa.resample(y, orig_sr=48000, target_sr=16000)
    batch["audio"]["array"] = y_resampled
    batch["audio"]["sampling_rate"] = 16000
    return batch


common_voice_train = common_voice_train.cast_column("audio", Audio(sampling_rate=48000))
common_voice_train = common_voice_train.map(resample_audio_librosa)
common_voice_test = common_voice_test.cast_column("audio", Audio(sampling_rate=48000))
common_voice_test = common_voice_test.map(resample_audio_librosa)

# %% [markdown]
# ### Tokenization and Feature Extraction -> Processor
#
# ---

# %%
tokenizer = Wav2Vec2CTCTokenizer(
    vocab_file=vocab_file,
    unk_token="[UNK]",
    pad_token="[PAD]",
    bos_token="<s>",
    eos_token="</s>",
    word_delimiter_token="|"
)

feature_extractor = Wav2Vec2FeatureExtractor(
    feature_size=1,
    sampling_rate=16000,
    padding_value=0.0,
    do_normalize=True,
    return_attention_mask=True
)

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %% [markdown]
# ### Data Collator

# %%
def prepare_dataset(batch):
    audio = batch["audio"]["array"]
    inputs = processor(audio, sampling_rate=16000, return_tensors="pt")

    with processor.as_target_processor():
        labels = processor(batch["sentence"], return_tensors="pt")

    return {
        "input_values": inputs.input_values,
        "labels": labels.input_ids
    }

common_voice_train = common_voice_train.map(prepare_dataset, remove_columns=common_voice_train.column_names)
common_voice_test = common_voice_test.map(prepare_dataset, remove_columns=common_voice_test.column_names)
# Out:
# Map:   0%|          | 0/2217 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:156: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/5212 [00:00<?, ? examples/s]

# %%
# from dataclasses import dataclass, field
# from typing import Any, Dict, List, Union

# @dataclass
# class DataCollatorCTCWithPadding:
#     processor: Wav2Vec2Processor
#     padding: Union[bool, str] = True

#     def __call__(self, features: List[Dict[str, Union[List[int], np.ndarray, Dict[str, np.ndarray]]]]) -> Dict[str, torch.Tensor]:
#         input_features = [{"input_values": feature["input_values"]} for feature in features]
#         label_features = [{"input_ids": feature["labels"]} for feature in features]

#         batch = self.processor.pad(
#             input_features,
#             padding=self.padding,
#             return_tensors="pt",
#         )
#         with self.processor.as_target_processor():
#             labels_batch = self.processor.pad(
#                 label_features,
#                 padding=self.padding,
#                 return_tensors="pt",
#             )

#         labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

#         batch["labels"] = labels

#         return batch

# data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %%
data_collator = DataCollatorWithPadding(tokenizer=processor.tokenizer, padding=True)

# %% [markdown]
# ### Evaluation Metric

# %%
wer_metric = load_metric("wer")

def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)
    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id
    pred_str = processor.batch_decode(pred_ids)
    labels_str = processor.batch_decode(pred.label_ids, group_tokens=False)
    wer = wer_metric.compute(predictions=pred_str, references=labels_str)
    return {"wer": wer}
# Out:
# <ipython-input-18-42c83d9cc2c5>:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   wer_metric = load_metric("wer")

# %% [markdown]
# ### Load Model

# %%
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-large-xlsr-53",
                                       gradient_checkpointing=True,
                                       ctc_loss_reduction="mean",
                                       pad_token_id=processor.tokenizer.pad_token_id)

model.freeze_feature_extractor()
# Out:
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-xlsr-53 and are newly initialized: ['lm_head.bias', 'lm_head.weight', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:2274: FutureWarning: The method `freeze_feature_extractor` is deprecated and will be removed in Transformers v5. Please use the equivalent `freeze_feature_encoder` method instead.
#   warnings.warn(

# %%
# !pip show accelerate
# Out:
# Name: accelerate
# Version: 0.31.0
# Summary: Accelerate
# Home-page: https://github.com/huggingface/accelerate
# Author: The HuggingFace team
# Author-email: zach.mueller@huggingface.co
# License: Apache
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: huggingface-hub, numpy, packaging, psutil, pyyaml, safetensors, torch
# Required-by:

# %%
training_args = TrainingArguments(
    output_dir="./wav2vec2-large-xlsr-persian-demo",
    group_by_length=True,
    per_device_train_batch_size=16,
    evaluation_strategy="steps",
    num_train_epochs=5,
    fp16=True,
    gradient_checkpointing=True,
    save_steps=500,
    eval_steps=500,
    logging_steps=500,
    learning_rate=1e-4,
    warmup_steps=1000,
    save_total_limit=2,
)

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=common_voice_train,
    eval_dataset=common_voice_test,
    tokenizer=processor.feature_extractor,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
start_time = time.time()
trainer.train()
end_time = time.time()
train_time = end_time - start_time
print(f"Training time: {train_time} seconds")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-5eb89ef1dc8e> in <cell line: 2>()
#       1 start_time = time.time()
# ----> 2 trainer.train()
#       3 end_time = time.time()
#       4 train_time = end_time - start_time
#       5 print(f"Training time: {train_time} seconds")
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1883                 hf_hub_utils.enable_progress_bars()
#    1884         else:
# -> 1885             return inner_training_loop(
#    1886                 args=args,
#    1887                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2176
#    2177             step = -1
# -> 2178             for step, inputs in enumerate(epoch_iterator):
#    2179                 total_batched_samples += 1
#    2180
#
# /usr/local/lib/python3.10/dist-packages/accelerate/data_loader.py in __iter__(self)
#     452         # We iterate one batch ahead to check when we are at the end
#     453         try:
# --> 454             current_batch = next(dataloader_iter)
#     455         except StopIteration:
#     456             yield
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     673     def _next_data(self):
#     674         index = self._next_index()  # may raise StopIteration
# --> 675         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676         if self._pin_memory:
#     677             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
# ---> 54         return self.collate_fn(data)
#
# /usr/local/lib/python3.10/dist-packages/transformers/data/data_collator.py in __call__(self, features)
#     269
#     270     def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, Any]:
# --> 271         batch = pad_without_fast_tokenizer_warning(
#     272             self.tokenizer,
#     273             features,
#
# /usr/local/lib/python3.10/dist-packages/transformers/data/data_collator.py in pad_without_fast_tokenizer_warning(tokenizer, *pad_args, **pad_kwargs)
#      64
#      65     try:
# ---> 66         padded = tokenizer.pad(*pad_args, **pad_kwargs)
#      67     finally:
#      68         # Restore the state of the warning.
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in pad(self, encoded_inputs, padding, max_length, pad_to_multiple_of, return_attention_mask, return_tensors, verbose)
#    3297         # The model's main input name, usually `input_ids`, has be passed for padding
#    3298         if self.model_input_names[0] not in encoded_inputs:
# -> 3299             raise ValueError(
#    3300                 "You should supply an encoding or a list of encodings to this method "
#    3301                 f"that includes {self.model_input_names[0]}, but you provided {list(encoded_inputs.keys())}"
#
# ValueError: You should supply an encoding or a list of encodings to this method that includes input_ids, but you provided ['input_values', 'labels']

# %%
print("Trainable weights:")
total_trainable_params = 0
for name, param in model.named_parameters():
    if param.requires_grad:
        num_params = param.numel()
        print(f"{name}: {num_params}")
        total_trainable_params += num_params

print(f"Total Trainable Parameters: {total_trainable_params}")
# Out:
# Trainable weights:
# wav2vec2.masked_spec_embed: 1024
# wav2vec2.feature_projection.layer_norm.weight: 512
# wav2vec2.feature_projection.layer_norm.bias: 512
# wav2vec2.feature_projection.projection.weight: 524288
# wav2vec2.feature_projection.projection.bias: 1024
# wav2vec2.encoder.pos_conv_embed.conv.bias: 1024
# wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0: 128
# wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1: 8388608
# wav2vec2.encoder.layer_norm.weight: 1024
# wav2vec2.encoder.layer_norm.bias: 1024
# wav2vec2.encoder.layers.0.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.0.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.0.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.0.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.0.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.0.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.0.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.0.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.0.layer_norm.weight: 1024
# wav2vec2.encoder.layers.0.layer_norm.bias: 1024
# wav2vec2.encoder.layers.0.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.0.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.0.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.0.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.0.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.0.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.1.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.1.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.1.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.1.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.1.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.1.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.1.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.1.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.1.layer_norm.weight: 1024
# wav2vec2.encoder.layers.1.layer_norm.bias: 1024
# wav2vec2.encoder.layers.1.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.1.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.1.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.1.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.1.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.1.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.2.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.2.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.2.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.2.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.2.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.2.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.2.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.2.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.2.layer_norm.weight: 1024
# wav2vec2.encoder.layers.2.layer_norm.bias: 1024
# wav2vec2.encoder.layers.2.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.2.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.2.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.2.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.2.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.2.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.3.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.3.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.3.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.3.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.3.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.3.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.3.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.3.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.3.layer_norm.weight: 1024
# wav2vec2.encoder.layers.3.layer_norm.bias: 1024
# wav2vec2.encoder.layers.3.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.3.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.3.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.3.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.3.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.3.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.4.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.4.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.4.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.4.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.4.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.4.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.4.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.4.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.4.layer_norm.weight: 1024
# wav2vec2.encoder.layers.4.layer_norm.bias: 1024
# wav2vec2.encoder.layers.4.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.4.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.4.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.4.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.4.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.4.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.5.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.5.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.5.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.5.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.5.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.5.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.5.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.5.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.5.layer_norm.weight: 1024
# wav2vec2.encoder.layers.5.layer_norm.bias: 1024
# wav2vec2.encoder.layers.5.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.5.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.5.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.5.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.5.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.5.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.6.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.6.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.6.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.6.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.6.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.6.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.6.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.6.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.6.layer_norm.weight: 1024
# wav2vec2.encoder.layers.6.layer_norm.bias: 1024
# wav2vec2.encoder.layers.6.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.6.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.6.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.6.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.6.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.6.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.7.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.7.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.7.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.7.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.7.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.7.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.7.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.7.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.7.layer_norm.weight: 1024
# wav2vec2.encoder.layers.7.layer_norm.bias: 1024
# wav2vec2.encoder.layers.7.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.7.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.7.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.7.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.7.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.7.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.8.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.8.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.8.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.8.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.8.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.8.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.8.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.8.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.8.layer_norm.weight: 1024
# wav2vec2.encoder.layers.8.layer_norm.bias: 1024
# wav2vec2.encoder.layers.8.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.8.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.8.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.8.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.8.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.8.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.9.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.9.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.9.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.9.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.9.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.9.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.9.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.9.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.9.layer_norm.weight: 1024
# wav2vec2.encoder.layers.9.layer_norm.bias: 1024
# wav2vec2.encoder.layers.9.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.9.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.9.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.9.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.9.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.9.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.10.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.10.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.10.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.10.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.10.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.10.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.10.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.10.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.10.layer_norm.weight: 1024
# wav2vec2.encoder.layers.10.layer_norm.bias: 1024
# wav2vec2.encoder.layers.10.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.10.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.10.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.10.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.10.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.10.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.11.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.11.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.11.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.11.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.11.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.11.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.11.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.11.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.11.layer_norm.weight: 1024
# wav2vec2.encoder.layers.11.layer_norm.bias: 1024
# wav2vec2.encoder.layers.11.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.11.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.11.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.11.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.11.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.11.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.12.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.12.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.12.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.12.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.12.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.12.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.12.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.12.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.12.layer_norm.weight: 1024
# wav2vec2.encoder.layers.12.layer_norm.bias: 1024
# wav2vec2.encoder.layers.12.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.12.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.12.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.12.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.12.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.12.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.13.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.13.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.13.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.13.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.13.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.13.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.13.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.13.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.13.layer_norm.weight: 1024
# wav2vec2.encoder.layers.13.layer_norm.bias: 1024
# wav2vec2.encoder.layers.13.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.13.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.13.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.13.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.13.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.13.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.14.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.14.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.14.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.14.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.14.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.14.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.14.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.14.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.14.layer_norm.weight: 1024
# wav2vec2.encoder.layers.14.layer_norm.bias: 1024
# wav2vec2.encoder.layers.14.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.14.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.14.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.14.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.14.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.14.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.15.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.15.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.15.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.15.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.15.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.15.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.15.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.15.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.15.layer_norm.weight: 1024
# wav2vec2.encoder.layers.15.layer_norm.bias: 1024
# wav2vec2.encoder.layers.15.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.15.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.15.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.15.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.15.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.15.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.16.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.16.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.16.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.16.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.16.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.16.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.16.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.16.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.16.layer_norm.weight: 1024
# wav2vec2.encoder.layers.16.layer_norm.bias: 1024
# wav2vec2.encoder.layers.16.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.16.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.16.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.16.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.16.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.16.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.17.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.17.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.17.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.17.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.17.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.17.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.17.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.17.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.17.layer_norm.weight: 1024
# wav2vec2.encoder.layers.17.layer_norm.bias: 1024
# wav2vec2.encoder.layers.17.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.17.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.17.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.17.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.17.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.17.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.18.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.18.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.18.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.18.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.18.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.18.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.18.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.18.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.18.layer_norm.weight: 1024
# wav2vec2.encoder.layers.18.layer_norm.bias: 1024
# wav2vec2.encoder.layers.18.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.18.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.18.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.18.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.18.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.18.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.19.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.19.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.19.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.19.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.19.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.19.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.19.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.19.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.19.layer_norm.weight: 1024
# wav2vec2.encoder.layers.19.layer_norm.bias: 1024
# wav2vec2.encoder.layers.19.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.19.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.19.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.19.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.19.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.19.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.20.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.20.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.20.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.20.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.20.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.20.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.20.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.20.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.20.layer_norm.weight: 1024
# wav2vec2.encoder.layers.20.layer_norm.bias: 1024
# wav2vec2.encoder.layers.20.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.20.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.20.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.20.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.20.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.20.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.21.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.21.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.21.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.21.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.21.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.21.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.21.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.21.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.21.layer_norm.weight: 1024
# wav2vec2.encoder.layers.21.layer_norm.bias: 1024
# wav2vec2.encoder.layers.21.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.21.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.21.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.21.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.21.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.21.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.22.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.22.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.22.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.22.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.22.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.22.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.22.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.22.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.22.layer_norm.weight: 1024
# wav2vec2.encoder.layers.22.layer_norm.bias: 1024
# wav2vec2.encoder.layers.22.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.22.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.22.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.22.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.22.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.22.final_layer_norm.bias: 1024
# wav2vec2.encoder.layers.23.attention.k_proj.weight: 1048576
# wav2vec2.encoder.layers.23.attention.k_proj.bias: 1024
# wav2vec2.encoder.layers.23.attention.v_proj.weight: 1048576
# wav2vec2.encoder.layers.23.attention.v_proj.bias: 1024
# wav2vec2.encoder.layers.23.attention.q_proj.weight: 1048576
# wav2vec2.encoder.layers.23.attention.q_proj.bias: 1024
# wav2vec2.encoder.layers.23.attention.out_proj.weight: 1048576
# wav2vec2.encoder.layers.23.attention.out_proj.bias: 1024
# wav2vec2.encoder.layers.23.layer_norm.weight: 1024
# wav2vec2.encoder.layers.23.layer_norm.bias: 1024
# wav2vec2.encoder.layers.23.feed_forward.intermediate_dense.weight: 4194304
# wav2vec2.encoder.layers.23.feed_forward.intermediate_dense.bias: 4096
# wav2vec2.encoder.layers.23.feed_forward.output_dense.weight: 4194304
# wav2vec2.encoder.layers.23.feed_forward.output_dense.bias: 1024
# wav2vec2.encoder.layers.23.final_layer_norm.weight: 1024
# wav2vec2.encoder.layers.23.final_layer_norm.bias: 1024
# lm_head.weight: 32768
# lm_head.bias: 32
# Total Trainable Parameters: 311261344
